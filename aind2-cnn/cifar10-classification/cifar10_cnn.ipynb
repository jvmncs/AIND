# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 32, 32, 32)        416
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 32, 32, 32)        4128
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 16, 16, 64)        8256
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 16, 16, 64)        16448
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 8, 8, 128)         32896
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 8, 8, 128)         65664
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 500)               1024500
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 500)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 1,157,318.0
# Trainable params: 1,157,318.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
early = EarlyStopping(patience=3)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer, early], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 1.33815, saving model to model.weights.best.hdf5
# 9s - loss: 1.6528 - acc: 0.3892 - val_loss: 1.3382 - val_acc: 0.5136
# Epoch 2/100
# Epoch 00001: val_loss improved from 1.33815 to 1.04100, saving model to model.weights.best.hdf5
# 8s - loss: 1.2144 - acc: 0.5628 - val_loss: 1.0410 - val_acc: 0.6276
# Epoch 3/100
# Epoch 00002: val_loss improved from 1.04100 to 0.97386, saving model to model.weights.best.hdf5
# 8s - loss: 1.0624 - acc: 0.6212 - val_loss: 0.9739 - val_acc: 0.6420
# Epoch 4/100
# Epoch 00003: val_loss improved from 0.97386 to 0.88874, saving model to model.weights.best.hdf5
# 8s - loss: 0.9653 - acc: 0.6553 - val_loss: 0.8887 - val_acc: 0.6720
# Epoch 5/100
# Epoch 00004: val_loss improved from 0.88874 to 0.83801, saving model to model.weights.best.hdf5
# 8s - loss: 0.9030 - acc: 0.6786 - val_loss: 0.8380 - val_acc: 0.7018
# Epoch 6/100
# Epoch 00005: val_loss improved from 0.83801 to 0.77696, saving model to model.weights.best.hdf5
# 8s - loss: 0.8517 - acc: 0.6998 - val_loss: 0.7770 - val_acc: 0.7242
# Epoch 7/100
# Epoch 00006: val_loss improved from 0.77696 to 0.75829, saving model to model.weights.best.hdf5
# 8s - loss: 0.8090 - acc: 0.7121 - val_loss: 0.7583 - val_acc: 0.7318
# Epoch 8/100
# Epoch 00007: val_loss improved from 0.75829 to 0.75119, saving model to model.weights.best.hdf5
# 8s - loss: 0.7676 - acc: 0.7295 - val_loss: 0.7512 - val_acc: 0.7304
# Epoch 9/100
# Epoch 00008: val_loss improved from 0.75119 to 0.71307, saving model to model.weights.best.hdf5
# 8s - loss: 0.7409 - acc: 0.7394 - val_loss: 0.7131 - val_acc: 0.7428
# Epoch 10/100
# Epoch 00009: val_loss improved from 0.71307 to 0.71039, saving model to model.weights.best.hdf5
# 8s - loss: 0.7106 - acc: 0.7505 - val_loss: 0.7104 - val_acc: 0.7490
# Epoch 11/100
# Epoch 00010: val_loss improved from 0.71039 to 0.66008, saving model to model.weights.best.hdf5
# 8s - loss: 0.6944 - acc: 0.7558 - val_loss: 0.6601 - val_acc: 0.7668
# Epoch 12/100
# Epoch 00011: val_loss did not improve
# 8s - loss: 0.6764 - acc: 0.7604 - val_loss: 0.6640 - val_acc: 0.7654
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 8s - loss: 0.6536 - acc: 0.7679 - val_loss: 0.6808 - val_acc: 0.7612
# Epoch 14/100
# Epoch 00013: val_loss did not improve
# 8s - loss: 0.6370 - acc: 0.7740 - val_loss: 0.6710 - val_acc: 0.7664
# Epoch 15/100
# Epoch 00014: val_loss improved from 0.66008 to 0.65858, saving model to model.weights.best.hdf5
# 8s - loss: 0.6215 - acc: 0.7811 - val_loss: 0.6586 - val_acc: 0.7758
# Epoch 16/100
# Epoch 00015: val_loss improved from 0.65858 to 0.65735, saving model to model.weights.best.hdf5
# 8s - loss: 0.6096 - acc: 0.7844 - val_loss: 0.6574 - val_acc: 0.7732
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 8s - loss: 0.5965 - acc: 0.7902 - val_loss: 0.7231 - val_acc: 0.7552
# Epoch 18/100
# Epoch 00017: val_loss improved from 0.65735 to 0.65633, saving model to model.weights.best.hdf5
# 8s - loss: 0.5944 - acc: 0.7919 - val_loss: 0.6563 - val_acc: 0.7782
# Epoch 19/100
# Epoch 00018: val_loss improved from 0.65633 to 0.64905, saving model to model.weights.best.hdf5
# 8s - loss: 0.5776 - acc: 0.7960 - val_loss: 0.6491 - val_acc: 0.7824
# Epoch 20/100
# Epoch 00019: val_loss improved from 0.64905 to 0.60967, saving model to model.weights.best.hdf5
# 8s - loss: 0.5676 - acc: 0.7966 - val_loss: 0.6097 - val_acc: 0.7950
# Epoch 21/100
# Epoch 00020: val_loss did not improve
# 8s - loss: 0.5475 - acc: 0.8071 - val_loss: 0.6219 - val_acc: 0.7896
# Epoch 22/100
# Epoch 00021: val_loss did not improve
# 8s - loss: 0.5456 - acc: 0.8070 - val_loss: 0.6271 - val_acc: 0.7940
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 8s - loss: 0.5396 - acc: 0.8096 - val_loss: 0.6338 - val_acc: 0.7908
# Epoch 24/100
# Epoch 00023: val_loss did not improve
# 8s - loss: 0.5321 - acc: 0.8120 - val_loss: 0.6195 - val_acc: 0.7912

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.782

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
